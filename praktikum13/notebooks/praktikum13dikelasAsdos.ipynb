# %% [markdown]
# #Menghubungkan dengan google collab

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/MyDrive/praktikum_ml/praktikum13"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ###**BussnisUnderstanding**
# Tujuan : membantu perusahaan pelayaran atau pihak
# terkait memahami faktor faktor yang mempengaruhi keslamatan penumpang serta memprediksi kemungkinan selamatnya penumpang berdasarkan karakteristik tertentu.
#
# Manfaat :
# *   Memberikan insight untuk perbaikan sistem keslamatan dimasa depan
# *   Dapat digunakan untuk pelatihan model prediksi pada kasus serupa di indrustri transportasi

# %% [markdown]
# #Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# #Load Data Set

# %%
df = pd.read_csv(path + "/data/titanic_data.csv")
df.head()

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #Pemeriksaan Missing Values

# %%
print("\nJumlah Missing Values (Data Kosong) per Kolom:")
df.isnull().sum()
# Out:
# Jumlah Missing Values (Data Kosong) per Kolom:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# #Data Cleaning

# %% [markdown]
# ##Menghapus Kolom yang Tidak Digunakan

# %%
# Menghapus 'Cabin' (Missing Value besar), 'Name', dan 'Ticket' (teks unik)
df = df.drop(columns=['Cabin', 'Name', 'Ticket'], axis=1)

# %% [markdown]
# ##Visualisasi Distribusi dan Oulier Kolom age

# %%
df.boxplot(column=['Age'])
# Out:
# <Axes: >

# %% [markdown]
# ##Mengisi Nilai Kosong pada Kolom Age dengan Median

# %%
# Menggunakan median karena kolom Age memiliki outlier
df['Age'].fillna(df['Age'].median(), inplace=True)
# Out:
# /tmp/ipython-input-3289093014.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)

# %% [markdown]
# ##Mengisi Nilai Kosong pada Kolom Embarked dengan Modus

# %%
# Jumlah missing value Embarked sedikit (hanya 2)
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-699544575.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %% [markdown]
# ##Verifikasi Ulang Missing Values

# %%
print("\nMissing values setelah cleaning:")
df.isnull().sum()
# Out:
# Missing values setelah cleaning:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ##Encoding Data Kategorikal

# %%
# Mengubah nilai teks pada kolom 'Sex' dan 'Embarked' menjadi numerik
replacements = {
    'Sex': {'male': 0, 'female': 1},
    'Embarked': {'S': 0, 'C': 1, 'Q': 2}
}
df.replace(replacements, inplace=True)
# Out:
# /tmp/ipython-input-3254919462.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(replacements, inplace=True)

# %%
print("\nDataset setelah Encoding Kategorikal (Head):")
df.head()
# Out:
# Dataset setelah Encoding Kategorikal (Head):
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    0  22.0      1      0   7.2500         0
# 1            2         1       1    1  38.0      1      0  71.2833         1
# 2            3         1       3    1  26.0      0      0   7.9250         0
# 3            4         1       1    1  35.0      1      0  53.1000         0
# 4            5         0       3    0  35.0      0      0   8.0500         0

# %% [markdown]
# #Split Data dan Transformasi (Scaling)

# %% [markdown]
# ##Split Data Variabel X dan Y

# %%
# X = Fitur Input, y = Target Output ('Survived')
X = df.drop('Survived', axis=1)
y = df['Survived']

# %% [markdown]
# ##Transformasi Data (Scaling)

# %%
# Menggunakan RobustScaler (lebih tahan terhadap outlier dibanding StandardScaler)
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ##Membagi Data Latih dan Data Uji

# %%
# Data latih (80%) dan Data uji (20%)
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# #Modelling

# %%
X_train.shape
# Out:
# (712, 8)

# %%
X_train.shape[1]
# Out:
# 8

# %% [markdown]
# #Pembuatan Model Neural Network (Arsitektur ANN)

# %%
# TensorFlow/Keras untuk membangun ANN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

# Input Layer dan Hidden layer 1
model.add(Dense(16, activation='relu', input_shape=(X_train.shape[1],)))

# Input Layer dan Hidden layer 2
model.add(Dense(8, activation='relu'))

# Output Layer: 1 neuron, Sigmoid (Klasifikasi Biner)
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 289 (1.13 KB)
#  Trainable params: 289 (1.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #Kompilasi Model

# %%
model.compile(
    optimizer='adam', # Algoritma optimasi
    loss='binary_crossentropy', # Fungsi kerugian untuk klasifikasi biner
    metrics=['accuracy'] # Metrik evaluasi
)

# %% [markdown]
# #Early Stopping (Pencegahan Overfitting)

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(
    monitor='val_loss', # Memantau Validation Loss
    patience=5, # Menunggu 5 epoch tanpa perbaikan
    restore_best_weights=True # Mengembalikan bobot terbaik
)

# %% [markdown]
# #Training Model Neural Network

# %%
print("\nMemulai Training Model...")
history = model.fit(
    X_train,
    y_train,
    epochs=50, # Max epoch
    batch_size=32, # Ukuran batch
    validation_split=0.2, # 20% data latih menjadi data validasi
    verbose=1
)
# Out:
# Memulai Training Model...
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4142 - loss: 0.7192 - val_accuracy: 0.5105 - val_loss: 0.7129
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5613 - loss: 0.6763 - val_accuracy: 0.6154 - val_loss: 0.6883
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6436 - loss: 0.6692 - val_accuracy: 0.6294 - val_loss: 0.6707
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6525 - loss: 0.6520 - val_accuracy: 0.6783 - val_loss: 0.6562
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6821 - loss: 0.6311 - val_accuracy: 0.6923 - val_loss: 0.6441
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7012 - loss: 0.6240 - val_accuracy: 0.7063 - val_loss: 0.6328
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7404 - loss: 0.6055 - val_accuracy: 0.7133 - val_loss: 0.6223
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7312 - loss: 0.5927 - val_accuracy: 0.7203 - val_loss: 0.6104
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7699 - loss: 0.5704 - val_accuracy: 0.7273 - val_loss: 0.5988
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7498 - loss: 0.5663 - val_accuracy: 0.7413 - val_loss: 0.5885
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7697 - loss: 0.5658 - val_accuracy: 0.7552 - val_loss: 0.5764
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7736 - loss: 0.5448 - val_accuracy: 0.7483 - val_loss: 0.5647
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7920 - loss: 0.5463 - val_accuracy: 0.7483 - val_loss: 0.5530
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7639 - loss: 0.5376 - val_accuracy: 0.7483 - val_loss: 0.5414
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8053 - loss: 0.4947 - val_accuracy: 0.7483 - val_loss: 0.5308
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7633 - loss: 0.5298 - val_accuracy: 0.7483 - val_loss: 0.5204
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7827 - loss: 0.5114 - val_accuracy: 0.7483 - val_loss: 0.5090
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8214 - loss: 0.4677 - val_accuracy: 0.7622 - val_loss: 0.4992
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7994 - loss: 0.4744 - val_accuracy: 0.7622 - val_loss: 0.4892
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8004 - loss: 0.4783 - val_accuracy: 0.7692 - val_loss: 0.4796
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.